# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("bcycle_data.csv")
df.head()
# Out:
#    station_last_updated  status_last_reported           station_id  \
# 0            1697507102            1697507104  bcycle_boulder_1855
# 1            1697507102            1697507104  bcycle_boulder_1858
# 2            1697507102            1697507104  bcycle_boulder_1859
# 3            1697507102            1697507104  bcycle_boulder_1860
# 4            1697507102            1697507104  bcycle_boulder_1861
#
#         station_name                 station_address  station_longitude  \
# 0  Folsom & Colorado  SE corner of Folsom & Colorado         -105.26385
# 1       15th & Pearl      15th Street & Pearl Street         -105.27584
# 2       11th & Pearl     11th Street & Pearl Street          -105.28116
# 3      13th & Spruce     13th Street & Spruce Street         -105.27890
# 4  UCAR Center Green         3080 Center Green Drive         -105.24611
#
#    station_latitude  station_is_returning  station_is_renting  \
# 0          40.00811                     1                   1
# ...

# %%
df.columns
# Out:
# Index(['station_last_updated', 'status_last_reported', 'station_id',
#        'station_name', 'station_address', 'station_longitude',
#        'station_latitude', 'station_is_returning', 'station_is_renting',
#        'station_is_installed', 'station_type', 'docks_available',
#        'bikes_available', 'electic_bikes_available', 'smart_bikes_available',
#        'classic_bikes_available', 'datatime_mtd'],
#       dtype='object')

# %%
col_name = ['station_last_updated', 'status_last_reported', 'station_id',
       'station_name', 'station_longitude',
       'station_latitude', 'station_is_returning', 'station_is_renting',
       'station_is_installed', 'docks_available',
       'bikes_available', 'datatime_mtd']
df = df[col_name]

# %%
df['datatime_mtd'] = pd.to_datetime(df['datatime_mtd'], format='%m-%d-%y %H:%M:%S')
# Out:
# c:\users\santh\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.loc[df['station_is_renting']==0]
# Out:
#         station_last_updated  status_last_reported           station_id  \
# 9785              1697556383            1697556385  bcycle_boulder_1873
# 9839              1697556565            1697556567  bcycle_boulder_1873
# 28055             1697617984            1697617985  bcycle_boulder_2766
# 28109             1697618166            1697618168  bcycle_boulder_2766
# 28113             1697618166            1697618168  bcycle_boulder_2770
# ...                      ...                   ...                  ...
# 172015            1698105652            1698105654  bcycle_boulder_2762
# 172069            1698105836            1698105838  bcycle_boulder_2762
# 188431            1698161540            1698161542  bcycle_boulder_2762
# 215971            1698255707            1698255710  bcycle_boulder_2762
# 216025            1698255893            1698255894  bcycle_boulder_2762
#
#                  station_name  station_longitude  station_latitude  \
# ...

# %%
df[]
# Out:
#         station_last_updated  status_last_reported           station_id  \
# 0                 1697507102            1697507104  bcycle_boulder_1855
# 1                 1697507102            1697507104  bcycle_boulder_1858
# 2                 1697507102            1697507104  bcycle_boulder_1859
# 3                 1697507102            1697507104  bcycle_boulder_1860
# 4                 1697507102            1697507104  bcycle_boulder_1861
# ...                      ...                   ...                  ...
# 225823            1698289165            1698289167  bcycle_boulder_7327
# 225824            1698289165            1698289167  bcycle_boulder_7345
# 225825            1698289165            1698289167  bcycle_boulder_7346
# 225826            1698289165            1698289167  bcycle_boulder_7387
# 225827            1698289165            1698289167  bcycle_boulder_7393
#
#                   station_name  station_longitude  station_latitude  \
# ...
